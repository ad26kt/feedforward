# %%
import numpy as np
import tensorflow as tf
import os
import sys
sys.path.insert(0, 'module')
import time
from tools import print_time
import cells
from tensorflow.examples.tutorials.mnist import input_data

mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# Data Related
TRAIN_SIZE = mnist.train.num_examples
VALID_SIZE = mnist.validation.num_examples
TEST_SIZE = mnist.test.num_examples
BATCH_SIZE = 500

# %%
# Save & Load
CKPT_DIR = 'checkpoint/fnn'

# %%
class fnn(object):
    def __init__(self, cell, lr, scope = None):
        with tf.variable_scope(scope or type(self).__name__):
            self.cell = cell
            self.inputs = tf.placeholder(dtype = tf.float32, shape = [None, cell.input_size], name = 'inputs')
            self.targets = tf.placeholder(dtype = tf.float32, shape = [None, cell.output_size], name = 'targets')
            self.global_step = tf.Variable(0, trainable = False, name = 'global_step')
            self.total_time = tf.Variable(0, dtype = tf.float32, trainable = True, name = 'total_time')

            # cell output
            self.output, self.state = cell(self.inputs)
            self.loss = tf.reduce_mean(-tf.reduce_sum(self.targets * tf.log(self.output), reduction_indices = [1]))
            tf.summary.scalar('loss', self.loss) # added

            # Training related
            self.params = tf.trainable_variables()
            self.gradients = tf.gradients(self.loss, self.params)
            self.opt_func = tf.train.GradientDescentOptimizer(lr)
            #clipped_gradients, norm = tf.clip_by_global_norm(gradients, 1)
            self.updates = self.opt_func.apply_gradients(zip(self.gradients, self.params), global_step = self.global_step)

            # Testing related
            self.correct_prediction = tf.equal(tf.argmax(self.output, 1), tf.argmax(self.targets, 1))
            self.accuracy = tf.reduce_mean(tf.cast(self.correct_prediction, tf.float32))

            # Save & Load related
            self.saver = tf.train.Saver(tf.global_variables(), max_to_keep = 5)
        
    def save(self, sess, ckpt_dir):
        ckpt_path = os.path.join(ckpt_dir, 'params.ckpt')
        self.saver.save(sess, ckpt_path, self.global_step)
    
    def check_and_load(self, sess, ckpt_dir):
        # Preparation for Save & Load
        if not os.path.exists(ckpt_dir):
            print 'Create directory for saving checkpoint...',
            os.makedirs(ckpt_dir)
            print 'Completed'
        else:
            print 'Checkpoint directory exists\n'
            
        ckpt = tf.train.get_checkpoint_state(ckpt_dir)
        
        # Check if checkpoint exists
        if ckpt:
            #print 'Read model parameters from %s... '%ckpt.model_checkpoint_path,
            self.saver.restore(sess, ckpt.model_checkpoint_path)
            print '\n'
        else:
            print 'Create new model...\n'
            sess.run(tf.global_variables_initializer())
        
    
    def train(self, sess, batch_gen, ckpt_dir, log_dir, max_epoch, patience, lr, lrdf, evaluate_per):
        '''
            args:
                batch_gen : batch generator with batch size, [train_gen, valid_gen, test_gen, batch_size]
                ckpt_dir : checkpoint directory
                log_dir : summary directory
                patience
                lr : learning rate
                lrdf : learning rate decay factor
        '''
        print('----------------------NN INFORMATION-----------------------')
        print('Input Size %d, Output Size %d' %(self.cell.input_size, self.cell.output_size))
        print('Stack Size %d, Hidden Size %d' %(self.cell.num_layer, self.cell.state_size))
        print('-----------------------------------------------------------\n')
        print ('---------------------BASIC PARAMETERS----------------------')
        print ('Batch size %d, Learning rate %f, Decay factor %f' %(batch_gen[-1], lr, lrdf))
        print ('Evaluate per %d iteration' %(evaluate_per))
        print ('Saving directory %s' %(ckpt_dir))
        print ('-----------------------------------------------------------')
        
        # Summary Writer
        merged = tf.summary.merge_all()
        
        train_writer = tf.summary.FileWriter(log_dir + '/train', sess.graph)
        valid_writer = tf.summary.FileWriter(log_dir + '/valid', sess.graph)
        
        train_gen, valid_gen, test_gen, batch_size = batch_gen
        
        # prevention for repetition
        valid_x, valid_y = valid_gen.next_batch(VALID_SIZE)
        test_x, test_y = test_gen.next_batch(TEST_SIZE)

        valid_input_feed = {self.inputs: valid_x, self.targets: valid_y}
        valid_output_feed = [merged, self.loss, self.accuracy]

        test_input_feed = {self.inputs: test_x, self.targets: test_y}
        test_output_feed = [self.loss, self.accuracy]
        
        self.check_and_load(sess, ckpt_dir)
        
        min_valid_loss = 9999
        iter_count = 0
        
        
        for epoch in xrange(max_epoch):
            iner_step = TRAIN_SIZE / batch_size # indicator for epoch completion
            # Time Check
            start_time = time.time()
            
            while True:
                try:
                    
                    train_x, train_y = train_gen.next_batch(batch_size)

                    input_feed = {self.inputs: train_x, self.targets: train_y}
                    output_feed = [merged, self.loss, self.updates]
                    summary, loss, _ = sess.run(output_feed, input_feed)
                    train_writer.add_summary(summary, iter_count)
                    
                    iter_count += 1
                    iner_step -= 1

                    # Evaluation step
                    if((self.global_step).eval() % evaluate_per == 0 and (self.global_step).eval() > 1):
                        
                        summary, valid_loss, accuracy = sess.run(valid_output_feed, valid_input_feed)
                        valid_writer.add_summary(summary, iter_count)
                        print 'Epoch : %3d | Evaluation : %4d | Learning Rate : %2.2f'%(epoch, self.global_step.eval()/evaluate_per, lr)
                        print '-------------------------------------------------------'
                        print '%-22s %10.5s'%('Training Loss :', loss)
                        print '%-22s %10.5s'%('Validation Loss :', valid_loss)
                        print '%-22s %10.5s'%('Best Validation loss :', min_valid_loss)
                        print '%-22s %10.5s%s'%('Validation Accuracy :', accuracy*100, '%')
                        
                        
                        # Check & Print training time
                        till_now = time.time() - start_time
                        sess.run(tf.assign(self.total_time, self.total_time + till_now)) # we must assign value to the tensor
                        print_time(self.total_time.eval())
                        
                        if valid_loss < min_valid_loss:
                            min_valid_loss = valid_loss
                            self.save(sess, ckpt_dir)
                    

                    # Check for one epoch completion
                    if iner_step == 0:
                        raise StopIteration

                except StopIteration:
                    break

# %%
tf.reset_default_graph()

# %%
cell = cells.FNNCell(784, 100, 1, 10)
batch_gen = [mnist.train, mnist.validation, mnist.test, BATCH_SIZE]

# %%
model = fnn(cell, 0.5)

# %%
sess = tf.InteractiveSession()

# %%
model.train(sess, batch_gen, CKPT_DIR, './', max_epoch = 10000, patience = 0, lr = 0.5, lrdf = 1, evaluate_per = 100)
# Out:
# ----------------------NN INFORMATION-----------------------
# Input Size 784, Output Size 10
# Stack Size 1, Hidden Size 100
# -----------------------------------------------------------
#
# ---------------------BASIC PARAMETERS----------------------
# Batch size 500, Learning rate 0.500000, Decay factor 1.000000
# Evaluate per 100 iteration
# Saving directory checkpoint/fnn
# -----------------------------------------------------------
# Checkpoint directory exists
#
# Create new model...
#
# Epoch :   0 | Evaluation :    1 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.537
# Validation Loss :           0.493
# Best Validation loss :       9999
# Validation Accuracy :       88.11%
# Total time cost : 0.53 seconds
#
# Epoch :   1 | Evaluation :    2 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.364
# Validation Loss :           0.365
# Best Validation loss :      0.493
# Validation Accuracy :       90.03%
# Total time cost : 0.90 seconds
#
# Epoch :   2 | Evaluation :    3 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.357
# Validation Loss :           0.321
# Best Validation loss :      0.365
# Validation Accuracy :       91.03%
# Total time cost : 1.21 seconds
#
# Epoch :   3 | Evaluation :    4 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.301
# Validation Loss :           0.295
# Best Validation loss :      0.321
# Validation Accuracy :       91.45%
# Total time cost : 1.50 seconds
#
# Epoch :   4 | Evaluation :    5 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.301
# Validation Loss :           0.279
# Best Validation loss :      0.295
# Validation Accuracy :       92.31%
# Total time cost : 1.76 seconds
#
# Epoch :   5 | Evaluation :    6 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.271
# Validation Loss :           0.266
# Best Validation loss :      0.279
# Validation Accuracy :       92.31%
# Total time cost : 2.00 seconds
#
# Epoch :   6 | Evaluation :    7 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.241
# Validation Loss :           0.254
# Best Validation loss :      0.266
# Validation Accuracy :       92.81%
# Total time cost : 2.18 seconds
#
# Epoch :   7 | Evaluation :    8 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.297
# Validation Loss :           0.247
# Best Validation loss :      0.254
# Validation Accuracy :       93.03%
# Total time cost : 2.36 seconds
#
# Epoch :   8 | Evaluation :    9 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.275
# Validation Loss :           0.237
# Best Validation loss :      0.247
# Validation Accuracy :       93.43%
# Total time cost : 2.50 seconds
#
# Epoch :   9 | Evaluation :   10 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.251
# Validation Loss :           0.227
# Best Validation loss :      0.237
# Validation Accuracy :       93.57%
# Total time cost : 2.59 seconds
#
# Epoch :   9 | Evaluation :   11 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.209
# Validation Loss :           0.221
# Best Validation loss :      0.227
# Validation Accuracy :       93.83%
# Total time cost : 3.00 seconds
#
# Epoch :  10 | Evaluation :   12 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.242
# Validation Loss :           0.214
# Best Validation loss :      0.221
# Validation Accuracy :       94.07%
# Total time cost : 3.37 seconds
#
# Epoch :  11 | Evaluation :   13 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.205
# Validation Loss :           0.209
# Best Validation loss :      0.214
# Validation Accuracy :       94.07%
# Total time cost : 3.70 seconds
#
# Epoch :  12 | Evaluation :   14 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.186
# Validation Loss :           0.203
# Best Validation loss :      0.209
# Validation Accuracy :       94.15%
# Total time cost : 4.00 seconds
#
# Epoch :  13 | Evaluation :   15 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.254
# Validation Loss :           0.198
# Best Validation loss :      0.203
# Validation Accuracy :       94.43%
# Total time cost : 4.26 seconds
#
# Epoch :  14 | Evaluation :   16 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.239
# Validation Loss :           0.191
# Best Validation loss :      0.198
# Validation Accuracy :       94.81%
# Total time cost : 4.52 seconds
#
# Epoch :  15 | Evaluation :   17 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.158
# Validation Loss :           0.186
# Best Validation loss :      0.191
# Validation Accuracy :       94.91%
# Total time cost : 4.75 seconds
#
# Epoch :  16 | Evaluation :   18 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.142
# Validation Loss :           0.182
# Best Validation loss :      0.186
# Validation Accuracy :       94.79%
# Total time cost : 4.95 seconds
#
# Epoch :  17 | Evaluation :   19 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.173
# Validation Loss :           0.177
# Best Validation loss :      0.182
# Validation Accuracy :       95.15%
# Total time cost : 5.10 seconds
#
# Epoch :  18 | Evaluation :   20 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.164
# Validation Loss :           0.173
# Best Validation loss :      0.177
# Validation Accuracy :       95.21%
# Total time cost : 5.23 seconds
#
# Epoch :  19 | Evaluation :   21 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.167
# Validation Loss :           0.169
# Best Validation loss :      0.173
# Validation Accuracy :       95.35%
# Total time cost : 5.33 seconds
#
# Epoch :  19 | Evaluation :   22 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.165
# Validation Loss :           0.165
# Best Validation loss :      0.169
# Validation Accuracy :       95.43%
# Total time cost : 5.72 seconds
#
# Epoch :  20 | Evaluation :   23 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.188
# Validation Loss :           0.162
# Best Validation loss :      0.165
# Validation Accuracy :       95.43%
# Total time cost : 6.07 seconds
#
# Epoch :  21 | Evaluation :   24 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.154
# Validation Loss :           0.158
# Best Validation loss :      0.162
# Validation Accuracy :       95.63%
# Total time cost : 6.43 seconds
#
# Epoch :  22 | Evaluation :   25 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.157
# Validation Loss :           0.155
# Best Validation loss :      0.158
# Validation Accuracy :       95.61%
# Total time cost : 6.73 seconds
#
# Epoch :  23 | Evaluation :   26 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.161
# Validation Loss :           0.153
# Best Validation loss :      0.155
# Validation Accuracy :       95.85%
# Total time cost : 7.00 seconds
#
# Epoch :  24 | Evaluation :   27 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.178
# Validation Loss :           0.149
# Best Validation loss :      0.153
# Validation Accuracy :       95.81%
# Total time cost : 7.25 seconds
#
# Epoch :  25 | Evaluation :   28 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.146
# Validation Loss :           0.147
# Best Validation loss :      0.149
# Validation Accuracy :       95.93%
# Total time cost : 7.46 seconds
#
# Epoch :  26 | Evaluation :   29 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.136
# Validation Loss :           0.143
# Best Validation loss :      0.147
# Validation Accuracy :       95.93%
# Total time cost : 7.66 seconds
#
# Epoch :  27 | Evaluation :   30 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.138
# Validation Loss :           0.141
# Best Validation loss :      0.143
# Validation Accuracy :       96.07%
# Total time cost : 7.84 seconds
#
# Epoch :  28 | Evaluation :   31 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.172
# Validation Loss :           0.139
# Best Validation loss :      0.141
# Validation Accuracy :       95.97%
# Total time cost : 7.99 seconds
#
# Epoch :  29 | Evaluation :   32 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.129
# Validation Loss :           0.136
# Best Validation loss :      0.139
# Validation Accuracy :       96.13%
# Total time cost : 8.10 seconds
#
# Epoch :  29 | Evaluation :   33 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.188
# Validation Loss :           0.135
# Best Validation loss :      0.136
# Validation Accuracy :       96.27%
# Total time cost : 8.57 seconds
#
# Epoch :  30 | Evaluation :   34 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.115
# Validation Loss :           0.133
# Best Validation loss :      0.135
# Validation Accuracy :       96.21%
# Total time cost : 8.92 seconds
#
# Epoch :  31 | Evaluation :   35 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.131
# Validation Loss :           0.130
# Best Validation loss :      0.133
# Validation Accuracy :       96.27%
# Total time cost : 9.22 seconds
#
# Epoch :  32 | Evaluation :   36 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.112
# Validation Loss :           0.129
# Best Validation loss :      0.130
# Validation Accuracy :       96.47%
# Total time cost : 9.53 seconds
#
# Epoch :  33 | Evaluation :   37 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.105
# Validation Loss :           0.126
# Best Validation loss :      0.129
# Validation Accuracy :       96.41%
# Total time cost : 9.84 seconds
#
# Epoch :  34 | Evaluation :   38 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.108
# Validation Loss :           0.125
# Best Validation loss :      0.126
# Validation Accuracy :       96.43%
# Total time cost : 10.11 seconds
#
# Epoch :  35 | Evaluation :   39 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.128
# Validation Loss :           0.124
# Best Validation loss :      0.125
# Validation Accuracy :       96.49%
# Total time cost : 10.32 seconds
#
# Epoch :  36 | Evaluation :   40 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.161
# Validation Loss :           0.121
# Best Validation loss :      0.124
# Validation Accuracy :       96.57%
# Total time cost : 10.50 seconds
#
# Epoch :  37 | Evaluation :   41 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.152
# Validation Loss :           0.121
# Best Validation loss :      0.121
# Validation Accuracy :       96.61%
# Total time cost : 10.66 seconds
#
# Epoch :  38 | Evaluation :   42 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.095
# Validation Loss :           0.119
# Best Validation loss :      0.121
# Validation Accuracy :       96.65%
# Total time cost : 10.80 seconds
#
# Epoch :  39 | Evaluation :   43 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.093
# Validation Loss :           0.117
# Best Validation loss :      0.119
# Validation Accuracy :       96.65%
# Total time cost : 10.91 seconds
#
# Epoch :  39 | Evaluation :   44 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.086
# Validation Loss :           0.115
# Best Validation loss :      0.117
# Validation Accuracy :       96.81%
# Total time cost : 11.36 seconds
#
# Epoch :  40 | Evaluation :   45 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.117
# Validation Loss :           0.114
# Best Validation loss :      0.115
# Validation Accuracy :       96.87%
# Total time cost : 11.72 seconds
#
# Epoch :  41 | Evaluation :   46 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.124
# Validation Loss :           0.113
# Best Validation loss :      0.114
# Validation Accuracy :       96.85%
# Total time cost : 12.06 seconds
#
# Epoch :  42 | Evaluation :   47 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.080
# Validation Loss :           0.112
# Best Validation loss :      0.113
# Validation Accuracy :       96.87%
# Total time cost : 12.37 seconds
#
# Epoch :  43 | Evaluation :   48 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.105
# Validation Loss :           0.110
# Best Validation loss :      0.112
# Validation Accuracy :       96.87%
# Total time cost : 12.66 seconds
#
# Epoch :  44 | Evaluation :   49 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.098
# Validation Loss :           0.109
# Best Validation loss :      0.110
# Validation Accuracy :       96.79%
# Total time cost : 12.92 seconds
#
# Epoch :  45 | Evaluation :   50 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.105
# Validation Loss :           0.108
# Best Validation loss :      0.109
# Validation Accuracy :       96.95%
# Total time cost : 13.14 seconds
#
# Epoch :  46 | Evaluation :   51 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.103
# Validation Loss :           0.107
# Best Validation loss :      0.108
# Validation Accuracy :       97.01%
# Total time cost : 13.33 seconds
#
# Epoch :  47 | Evaluation :   52 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.080
# Validation Loss :           0.106
# Best Validation loss :      0.107
# Validation Accuracy :       97.07%
# Total time cost : 13.48 seconds
#
# Epoch :  48 | Evaluation :   53 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.092
# Validation Loss :           0.105
# Best Validation loss :      0.106
# Validation Accuracy :       97.07%
# Total time cost : 13.63 seconds
#
# Epoch :  49 | Evaluation :   54 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.089
# Validation Loss :           0.104
# Best Validation loss :      0.105
# Validation Accuracy :       97.05%
# Total time cost : 13.75 seconds
#
# Epoch :  49 | Evaluation :   55 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.071
# Validation Loss :           0.103
# Best Validation loss :      0.104
# Validation Accuracy :       97.15%
# Total time cost : 14.17 seconds
#
# Epoch :  50 | Evaluation :   56 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.098
# Validation Loss :           0.102
# Best Validation loss :      0.103
# Validation Accuracy :       97.15%
# Total time cost : 14.49 seconds
#
# Epoch :  51 | Evaluation :   57 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.097
# Validation Loss :           0.100
# Best Validation loss :      0.102
# Validation Accuracy :       97.23%
# Total time cost : 14.83 seconds
#
# Epoch :  52 | Evaluation :   58 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.097
# Validation Loss :           0.100
# Best Validation loss :      0.100
# Validation Accuracy :       97.23%
# Total time cost : 15.13 seconds
#
# Epoch :  53 | Evaluation :   59 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.144
# Validation Loss :           0.099
# Best Validation loss :      0.100
# Validation Accuracy :       97.25%
# Total time cost : 15.41 seconds
#
# Epoch :  54 | Evaluation :   60 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.084
# Validation Loss :           0.099
# Best Validation loss :      0.099
# Validation Accuracy :       97.25%
# Total time cost : 15.67 seconds
#
# Epoch :  55 | Evaluation :   61 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.056
# Validation Loss :           0.097
# Best Validation loss :      0.099
# Validation Accuracy :       97.33%
# Total time cost : 15.90 seconds
#
# Epoch :  56 | Evaluation :   62 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.090
# Validation Loss :           0.097
# Best Validation loss :      0.097
# Validation Accuracy :       97.37%
# Total time cost : 16.09 seconds
#
# Epoch :  57 | Evaluation :   63 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.101
# Validation Loss :           0.096
# Best Validation loss :      0.097
# Validation Accuracy :       97.39%
# Total time cost : 16.26 seconds
#
# Epoch :  58 | Evaluation :   64 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.100
# Validation Loss :           0.095
# Best Validation loss :      0.096
# Validation Accuracy :       97.31%
# Total time cost : 16.40 seconds
#
# Epoch :  59 | Evaluation :   65 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.064
# Validation Loss :           0.095
# Best Validation loss :      0.095
# Validation Accuracy :       97.37%
# Total time cost : 16.51 seconds
#
# Epoch :  59 | Evaluation :   66 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.068
# Validation Loss :           0.094
# Best Validation loss :      0.095
# Validation Accuracy :       97.43%
# Total time cost : 16.95 seconds
#
# Epoch :  60 | Evaluation :   67 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.072
# Validation Loss :           0.093
# Best Validation loss :      0.094
# Validation Accuracy :       97.37%
# Total time cost : 17.32 seconds
#
# Epoch :  61 | Evaluation :   68 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.078
# Validation Loss :           0.092
# Best Validation loss :      0.093
# Validation Accuracy :       97.45%
# Total time cost : 17.64 seconds
#
# Epoch :  62 | Evaluation :   69 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.053
# Validation Loss :           0.092
# Best Validation loss :      0.092
# Validation Accuracy :       97.49%
# Total time cost : 17.94 seconds
#
# Epoch :  63 | Evaluation :   70 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.053
# Validation Loss :           0.092
# Best Validation loss :      0.092
# Validation Accuracy :       97.43%
# Total time cost : 18.21 seconds
#
# Epoch :  64 | Evaluation :   71 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.047
# Validation Loss :           0.090
# Best Validation loss :      0.092
# Validation Accuracy :       97.45%
# Total time cost : 18.46 seconds
#
# Epoch :  65 | Evaluation :   72 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.066
# Validation Loss :           0.090
# Best Validation loss :      0.090
# Validation Accuracy :       97.43%
# Total time cost : 18.67 seconds
#
# Epoch :  66 | Evaluation :   73 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.092
# Validation Loss :           0.089
# Best Validation loss :      0.090
# Validation Accuracy :       97.51%
# Total time cost : 18.84 seconds
#
# Epoch :  67 | Evaluation :   74 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.066
# Validation Loss :           0.089
# Best Validation loss :      0.089
# Validation Accuracy :       97.55%
# Total time cost : 19.00 seconds
#
# Epoch :  68 | Evaluation :   75 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.074
# Validation Loss :           0.088
# Best Validation loss :      0.089
# Validation Accuracy :       97.59%
# Total time cost : 19.14 seconds
#
# Epoch :  69 | Evaluation :   76 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.078
# Validation Loss :           0.088
# Best Validation loss :      0.088
# Validation Accuracy :       97.43%
# Total time cost : 19.26 seconds
#
# Epoch :  69 | Evaluation :   77 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.049
# Validation Loss :           0.087
# Best Validation loss :      0.088
# Validation Accuracy :       97.55%
# Total time cost : 19.67 seconds
#
# Epoch :  70 | Evaluation :   78 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.062
# Validation Loss :           0.088
# Best Validation loss :      0.087
# Validation Accuracy :       97.49%
# Total time cost : 20.01 seconds
#
# Epoch :  71 | Evaluation :   79 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.064
# Validation Loss :           0.086
# Best Validation loss :      0.087
# Validation Accuracy :       97.59%
# Total time cost : 20.30 seconds
#
# Epoch :  72 | Evaluation :   80 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.090
# Validation Loss :           0.086
# Best Validation loss :      0.086
# Validation Accuracy :       97.51%
# Total time cost : 20.61 seconds
#
# Epoch :  73 | Evaluation :   81 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.059
# Validation Loss :           0.085
# Best Validation loss :      0.086
# Validation Accuracy :       97.57%
# Total time cost : 20.88 seconds
#
# Epoch :  74 | Evaluation :   82 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.052
# Validation Loss :           0.085
# Best Validation loss :      0.085
# Validation Accuracy :       97.65%
# Total time cost : 21.14 seconds
#
# Epoch :  75 | Evaluation :   83 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.061
# Validation Loss :           0.085
# Best Validation loss :      0.085
# Validation Accuracy :       97.57%
# Total time cost : 21.37 seconds
#
# Epoch :  76 | Evaluation :   84 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.074
# Validation Loss :           0.084
# Best Validation loss :      0.085
# Validation Accuracy :       97.59%
# Total time cost : 21.57 seconds
#
# Epoch :  77 | Evaluation :   85 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.045
# Validation Loss :           0.083
# Best Validation loss :      0.084
# Validation Accuracy :       97.59%
# Total time cost : 21.74 seconds
#
# Epoch :  78 | Evaluation :   86 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.074
# Validation Loss :           0.084
# Best Validation loss :      0.083
# Validation Accuracy :       97.51%
# Total time cost : 21.89 seconds
#
# Epoch :  79 | Evaluation :   87 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.044
# Validation Loss :           0.083
# Best Validation loss :      0.083
# Validation Accuracy :       97.63%
# Total time cost : 22.00 seconds
#
# Epoch :  79 | Evaluation :   88 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.044
# Validation Loss :           0.082
# Best Validation loss :      0.083
# Validation Accuracy :       97.55%
# Total time cost : 22.44 seconds
#
# Epoch :  80 | Evaluation :   89 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.058
# Validation Loss :           0.082
# Best Validation loss :      0.082
# Validation Accuracy :       97.59%
# Total time cost : 22.80 seconds
#
# Epoch :  81 | Evaluation :   90 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.044
# Validation Loss :           0.081
# Best Validation loss :      0.082
# Validation Accuracy :       97.63%
# Total time cost : 23.16 seconds
#
# Epoch :  82 | Evaluation :   91 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.063
# Validation Loss :           0.082
# Best Validation loss :      0.081
# Validation Accuracy :       97.59%
# Total time cost : 23.48 seconds
#
# Epoch :  83 | Evaluation :   92 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.050
# Validation Loss :           0.081
# Best Validation loss :      0.081
# Validation Accuracy :       97.61%
# Total time cost : 23.75 seconds
#
# Epoch :  84 | Evaluation :   93 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.054
# Validation Loss :           0.081
# Best Validation loss :      0.081
# Validation Accuracy :       97.69%
# Total time cost : 24.01 seconds
#
# Epoch :  85 | Evaluation :   94 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.058
# Validation Loss :           0.080
# Best Validation loss :      0.081
# Validation Accuracy :       97.67%
# Total time cost : 24.23 seconds
#
# Epoch :  86 | Evaluation :   95 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.048
# Validation Loss :           0.080
# Best Validation loss :      0.080
# Validation Accuracy :       97.67%
# Total time cost : 24.41 seconds
#
# Epoch :  87 | Evaluation :   96 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.026
# Validation Loss :           0.080
# Best Validation loss :      0.080
# Validation Accuracy :       97.61%
# Total time cost : 24.59 seconds
#
# Epoch :  88 | Evaluation :   97 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.048
# Validation Loss :           0.079
# Best Validation loss :      0.080
# Validation Accuracy :       97.67%
# Total time cost : 24.71 seconds
#
# Epoch :  89 | Evaluation :   98 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.036
# Validation Loss :           0.079
# Best Validation loss :      0.079
# Validation Accuracy :       97.65%
# Total time cost : 24.82 seconds
#
# Epoch :  89 | Evaluation :   99 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.063
# Validation Loss :           0.079
# Best Validation loss :      0.079
# Validation Accuracy :       97.63%
# Total time cost : 25.27 seconds
#
# Epoch :  90 | Evaluation :  100 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.046
# Validation Loss :           0.079
# Best Validation loss :      0.079
# Validation Accuracy :       97.57%
# Total time cost : 25.62 seconds
#
# Epoch :  91 | Evaluation :  101 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.068
# Validation Loss :           0.079
# Best Validation loss :      0.079
# Validation Accuracy :       97.65%
# Total time cost : 25.93 seconds
#
# Epoch :  92 | Evaluation :  102 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.041
# Validation Loss :           0.078
# Best Validation loss :      0.079
# Validation Accuracy :       97.65%
# Total time cost : 26.22 seconds
#
# Epoch :  93 | Evaluation :  103 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.047
# Validation Loss :           0.078
# Best Validation loss :      0.078
# Validation Accuracy :       97.63%
# Total time cost : 26.47 seconds
#
# Epoch :  94 | Evaluation :  104 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.062
# Validation Loss :           0.077
# Best Validation loss :      0.078
# Validation Accuracy :       97.69%
# Total time cost : 26.71 seconds
#
# Epoch :  95 | Evaluation :  105 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.045
# Validation Loss :           0.077
# Best Validation loss :      0.077
# Validation Accuracy :       97.65%
# Total time cost : 26.85 seconds
#
# Epoch :  96 | Evaluation :  106 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.051
# Validation Loss :           0.077
# Best Validation loss :      0.077
# Validation Accuracy :       97.65%
# Total time cost : 26.98 seconds
#
# Epoch :  97 | Evaluation :  107 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.048
# Validation Loss :           0.077
# Best Validation loss :      0.077
# Validation Accuracy :       97.59%
# Total time cost : 27.12 seconds
#
# Epoch :  98 | Evaluation :  108 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.060
# Validation Loss :           0.076
# Best Validation loss :      0.077
# Validation Accuracy :       97.63%
# Total time cost : 27.23 seconds
#
# Epoch :  99 | Evaluation :  109 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.030
# Validation Loss :           0.076
# Best Validation loss :      0.076
# Validation Accuracy :       97.59%
# Total time cost : 27.34 seconds
#
# Epoch :  99 | Evaluation :  110 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.040
# Validation Loss :           0.076
# Best Validation loss :      0.076
# Validation Accuracy :       97.69%
# Total time cost : 27.81 seconds
#
# Epoch : 100 | Evaluation :  111 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.039
# Validation Loss :           0.076
# Best Validation loss :      0.076
# Validation Accuracy :       97.63%
# Total time cost : 28.17 seconds
#
# Epoch : 101 | Evaluation :  112 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.053
# Validation Loss :           0.075
# Best Validation loss :      0.076
# Validation Accuracy :       97.63%
# Total time cost : 28.54 seconds
#
# Epoch : 102 | Evaluation :  113 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.056
# Validation Loss :           0.075
# Best Validation loss :      0.075
# Validation Accuracy :       97.65%
# Total time cost : 28.87 seconds
#
# Epoch : 103 | Evaluation :  114 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.028
# Validation Loss :           0.075
# Best Validation loss :      0.075
# Validation Accuracy :       97.63%
# Total time cost : 29.17 seconds
#
# Epoch : 104 | Evaluation :  115 | Learning Rate : 0.50
# -------------------------------------------------------
# Training Loss :             0.043
# Validation Loss :           0.075
# Best Validation loss :      0.075
# Validation Accuracy :       97.77%
# Total time cost : 29.42 seconds
